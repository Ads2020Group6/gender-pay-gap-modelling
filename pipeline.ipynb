# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
from data_collector import acquire_data
from data_cleaner import clean_data
from modelling_pipeline import main as train_all_models
# from select_best_model_and_explain import main as select_best_model_and_explain

# %%
df = acquire_data()
df['year'].value_counts()
# Out:
# ukgov-gpg-2017.csv already exists in 'data' folder
# ukgov-gpg-2018.csv already exists in 'data' folder
# ukgov-gpg-2019.csv already exists in 'data' folder
# sic_codes.csv already exists in 'data' folder
# 2018    10828
# 2017    10563
# 2019     5462
# Name: year, dtype: int64

# %%
df = clean_data(df)
df.describe()
# Out:
#        DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# count           62806.000000             62806.000000          62806.000000
# mean               14.161862                11.940391             16.287943
# std                14.863828                15.685252            500.077181
# min              -499.900000              -196.500000         -82000.000000
# 25%                 5.000000                 0.900000              0.000000
# 50%                13.200000                 9.500000             21.800000
# 75%                22.600000                21.100000             52.000000
# max               159.000000               121.200000           3848.200000
#
#        DiffMedianBonusPercent  MaleBonusPercent  FemaleBonusPercent  \
# count            62806.000000      62806.000000        62806.000000
# mean                -4.654632         35.922237           34.477201
# std                831.921101         36.765079           36.437628
# min            -120695.000000          0.000000            0.000000
# 25%                  0.000000          0.700000            0.300000
# 50%                 12.600000         19.700000           17.600000
# 75%                 37.200000         75.000000           72.100000
# max               4000.000000        100.000000          100.000000
#
#        MaleLowerQuartile  FemaleLowerQuartile  MaleLowerMiddleQuartile  \
# count       62806.000000         62806.000000             62806.000000
# mean           46.356571            53.643429                50.577311
# std            24.263329            24.263329                26.239311
# min             0.000000             0.000000                 0.000000
# 25%            27.000000            35.000000                29.325000
# 50%            44.800000            55.200000                48.800000
# 75%            65.000000            73.000000                73.000000
# max           100.000000           100.000000               100.000000
#
#        FemaleLowerMiddleQuartile  ...  SectorConstruction  \
# count               62806.000000  ...        62806.000000
# mean                   49.422689  ...            0.008439
# std                    26.239311  ...            0.091475
# min                     0.000000  ...            0.000000
# 25%                    27.000000  ...            0.000000
# 50%                    51.200000  ...            0.000000
# 75%                    70.675000  ...            0.000000
# max                   100.000000  ...            1.000000
#
#        SectorManufacturing  SectorUtilityServices  SectorWholesaleTrade  \
# count         62806.000000           62806.000000          62806.000000
# mean              0.108652               0.163726              0.006560
# std               0.311205               0.370030              0.080728
# min               0.000000               0.000000              0.000000
# 25%               0.000000               0.000000              0.000000
# 50%               0.000000               0.000000              0.000000
# 75%               0.000000               0.000000              0.000000
# max               1.000000               1.000000              1.000000
#
#        SectorRetailTrade  SectorFinancials  SectorServices  \
# count       62806.000000      62806.000000    62806.000000
# mean            0.082030          0.106375        0.482804
# std             0.274413          0.308320        0.499708
# min             0.000000          0.000000        0.000000
# 25%             0.000000          0.000000        0.000000
# 50%             0.000000          0.000000        0.000000
# 75%             0.000000          0.000000        1.000000
# max             1.000000          1.000000        1.000000
#
#        SectorPublicAdministration  SectorNonclassifiable  FirstSicCodeAsNum
# count                62806.000000           62806.000000       62806.000000
# mean                     0.059533               0.001736         499.278977
# std                      0.236621               0.041624         312.851293
# min                      0.000000               0.000000           0.010000
# 25%                      0.000000               0.000000         251.100000
# 50%                      0.000000               0.000000         551.000000
# 75%                      0.000000               0.000000         783.000000
# max                      1.000000               1.000000         999.990000
#
# [8 rows x 34 columns]

# %%
df = explode_industry_sector(df)
df = augment_features(df)
scores = train_all_models(df)
select_best_model_and_explain(scores)
